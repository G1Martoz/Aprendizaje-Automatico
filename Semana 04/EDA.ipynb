# %%
import pandas as pd

# 1. Carga del archivo (Asegúrate de que el nombre coincida exactamente con tu archivo)
df = pd.read_csv('Salary_Data.csv') 

# 2. Verificación de estructura
print("--- Información del dataset ---")
print(df.info())

# 3. Detección de valores nulos (La causa #1 de errores en modelos)
print("\n--- Valores nulos por columna ---")
print(df.isnull().sum())

# 4. Detección de duplicados
print(f"\nCantidad de filas duplicadas: {df.duplicated().sum()}")

# 5. Análisis de consistencia (Buscamos valores lógicos)
print("\n--- Estadísticas descriptivas ---")
print(df.describe())

# --- ACCIONES DE LIMPIEZA (Si detectas problemas) ---
# Si hubiera nulos, podrías usar: df = df.dropna()
# Si hubiera duplicados, podrías usar: df = df.drop_duplicates()
# Out:
# --- Información del dataset ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes
# None
#
# --- Valores nulos por columna ---
# YearsExperience    0
# Salary             0
# dtype: int64
#
# Cantidad de filas duplicadas: 0
#
# --- Estadísticas descriptivas ---
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000
